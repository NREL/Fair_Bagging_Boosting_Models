# %%
import os
import numpy as np 
import pandas as pd 
import warnings
from tools.test_bias import test_bias, train_test_bias
from tools.plotting import plot_bias
from tools.bias_utils import add_demographic_data
from tools.loss_functions import get_distance_corrected_mse, get_pearson_corrected_mse, get_kendalls_corrected_mse
from xgb_gradient_boosted_trees.gradient_boosted_trees import GradientBoostedTreesModel
from xgb_random_forest.random_forest import RandomForestModel
import json
import xgboost as xgb
warnings.filterwarnings("ignore")

# %%
figsize = np.array((25, 6))*1     # Setting the figures size

# %% [markdown]
# # This notebook tests bias for XGBoost, Gradient boosed tree (GBT) and Random Forest (RF) models using a statistically rigorous method.
#
# The overall group accuracy is used as fairness metric and ensures that the overall prediction accuracy for both disadvantaged and non-disadvantaged groups is equal. Additionally, we measures the significance of the bias detected. we identified a data point as part of a disadvantaged group in regard to a particular demographic d if its value for demographic d’s percentile that area was greater or equal to 0.6, 0.7, 0.8, and 0.9, with percentile values ranging from 0 to 1. We measured bias as the difference in R-square accuracy between disadvantaged group and non-disadvantaged group. A positive difference in R-squared accuracy indicates that the model’s R-squared was higher for the non-disadvantaged group compared to the disadvantaged group.
#
# ### The notebook assumes you already have pre-trained XGBoost, GBT, and RF models saved under 'base_models' folder
# These models are trained without consideration of bias. Our methodology is also applicable to other machine learning models that can be implemented using this XGBoost framework.
# * XGBoost model is saved under 'base_models/xgb/' directory
# * GBT model is saved under 'base_models/gbt/' directory
# * RF model is saved under 'base_models/rf/' directory

# %% [markdown]
# # Load Test Dataset

# %%
# convert dataframe to d_matrix, which is required for using custom loss function in xgboost library
def to_dmatrix(X, y):
        # get number of columns of np array X
        n_cols = X.shape[1]
        weights = [1.0 for _ in range(n_cols-1)] + [0.0]
        return xgb.DMatrix(X, label=y, feature_weights=weights)

# %%
# List of columns names of demongraphic attributes to test bias against
# The demongraphic attributes below are from the CDC vulnerability data set:
# https://www.atsdr.cdc.gov/placeandhealth/svi/documentation/SVI_documentation_2018.html
demographics = ['AGE17', 'AGE65', 'CROWD', 'DISABL', 'GROUPQ', 'LIMENG',
            'MINRTY', 'MOBILE', 'MUNIT', 'NOHSDP', 'NOVEH', 'PCI', 'POV',
            'SNGPNT', 'UNEMP']

# %%
# columns to drop from the training data. Skip this step if not needed for your application
cols_drop = ['Date', 'FC', 'PenRate', 'NumberOfLanes', 'Dir', 'Lat', 'Long']

# %%
raw_data_test = pd.read_csv("./data/final_test_data.csv")     # Reading in the testing data set

# map demographics attributes to training and testing data set
# The 'add_demographic_data' function is specific to the dataset used in our case study. You can modify it by
# going to 'tools/bias_utils.py' script and changing it according to your data set.
# Skip this step if your training and testing data already includes demographic attributes
raw_data_test = add_demographic_data(raw_data_test, demographics)

raw_data_test = raw_data_test.dropna()       # droping rows and columns with nans values

# drop all columns not necessary for testing bias. Skip if not needed for your dataset
data = raw_data_test.drop(cols_drop, axis=1)

# %%
# convert day of week names to numbers from 1 to 7
week_dict = {"DayOfWeek": {'Monday': 1, 'Tuesday': 2, 'Wednesday': 3, 'Thursday': 4, 
                            'Friday': 5, 'Saturday': 6, 'Sunday': 7}}
data = data.replace(week_dict)

# %%
# 'Volume' columen is what we re predicting, drop it from X_test and set it to y_test
X_test = data.drop(['Volume'], axis=1)
y_test = data[['Volume']]

# demographics data in the test dataset
dem_test = X_test[demographics]
# drop other unnecessary columns (in this case StationId) and demographics columns from X_test
X_test = X_test.drop(['StationId']+demographics, axis = 1).values

# convert testing data to dmatrix to enable calculating the correlation between the model's error and demographic data
dtest = to_dmatrix(X_test, y_test)

# %% [markdown]
# # XGBoost Model Bias Testing

# %%
# Loading the pre-trained XGBoost model
xgb_path = os.path.join('.', 'base_models', 'xgb', 'base_xgb.model')
xgb_model = xgb.Booster()
xgb_model.load_model(xgb_path)

# %%
# Calculate the bias and save it under 'base_models/xgb/'
path = os.path.join('.', 'base_models', 'xgb')
if not os.path.exists(os.path.join(path, 'xgb_bias_data.csv')):
    xgb_bias_data = test_bias(xgb_model, dtest, dem_test)
    xgb_bias_data.to_csv(os.path.join(path, 'xgb_bias_data.csv'), index=False)
else:
    xgb_bias_data = pd.read_csv(os.path.join(path, 'xgb_bias_data.csv'))

# %%
# Plot the measure bias and save the figure under 'base_models/xgb/'
fig_path = os.path.join(path, 'xgb_bias_plots.png')
plot_bias(xgb_bias_data, labels=demographics, savepath=fig_path, xlabel='Demographic', figsize=figsize, barlabels=False);

# %% [markdown]
# The above figure shows a bar graph of the demographic bias tests for the 15 CDC demographic variables for the XGB model. The symbol at the bottom of the bar represents the alpha-level for which the modelshowed significant bias in that demographic variable and percentile cutoff. The star symbol shows a high level of significance for the measured bias, while the triangle , while the circle indicates a medium significance level and the triangle shows a low level of significance.

# %% [markdown]
# # Random Forest Model Bias Testing

# %%
# Loading the pre-trained RF model
rf_path = os.path.join('.', 'base_models', 'rf', 'base_rf.model')
rf_model = RandomForestModel()
rf_model.load_model(rf_path)

# %%
# Calculate the bias and save it under 'base_models/rf/'
path = os.path.join('.', 'base_models', 'rf')
if not os.path.exists(os.path.join(path, 'rf_bias_data.csv')):
    rf_bias_data = test_bias(rf_model, dtest, dem_test)
    rf_bias_data.to_csv(os.path.join(path, 'rf_bias_data.csv'), index=False)
else:
    rf_bias_data = pd.read_csv(os.path.join(path, 'rf_bias_data.csv'))

# %%
# Plot the measure bias and save the figure under 'base_models/rf/'
fig_path = os.path.join(path, 'rf_bias_plots.png')
plot_bias(rf_bias_data, labels=demographics, savepath=fig_path, xlabel='Demographic', figsize=figsize, barlabels=False);

# %% [markdown]
# The above figure shows a bar graph of the demographic bias tests for the 15 CDC demographic variables for the RF model. The symbol at the bottom of the bar represents the alpha-level for which the modelshowed significant bias in that demographic variable and percentile cutoff. The star symbol shows a high level of significance for the measured bias, while the triangle , while the circle indicates a medium significance level and the triangle shows a low level of significance.

# %% [markdown]
# # Gradient Boosted Trees Model

# %%
# Loading the pre-trained GBT model
gbt_path = os.path.join('.', 'base_models', 'gbt', 'base_gbt.model')
gbt_model = GradientBoostedTreesModel()
gbt_model.load_model(gbt_path)

# %%
# Calculate the bias and save it under 'base_models/gbt/'
path = os.path.join('.', 'base_models', 'gbt')
if not os.path.exists(os.path.join(path, 'gbt_bias_data.csv')):
    gbt_bias_data = test_bias(gbt_model, dtest, dem_test)
    gbt_bias_data.to_csv(os.path.join(path, 'gbt_bias_data.csv'), index=False)
else:
    gbt_bias_data = pd.read_csv(os.path.join(path, 'gbt_bias_data.csv'))

# %%
# Plot the measure bias and save the figure under 'base_models/gbt/'
fig_path = os.path.join(path, 'gbt_bias_plots.png')
plot_bias(gbt_bias_data, labels=demographics, savepath=fig_path, xlabel='Demographic', figsize=figsize, barlabels=False);

# %% [markdown]
# The above figure shows a bar graph of the demographic bias tests for the 15 CDC demographic variables for the GBT model. The symbol at the bottom of the bar represents the alpha-level for which the modelshowed significant bias in that demographic variable and percentile cutoff. The star symbol shows a high level of significance for the measured bias, while the triangle , while the circle indicates a medium significance level and the triangle shows a low level of significance.
